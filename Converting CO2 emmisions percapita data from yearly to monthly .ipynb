# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import datasets
from sklearn.model_selection import train_test_split  
from sklearn import metrics
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
from sklearn import preprocessing
import itertools
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Loading Annual CO2 emissions data

# %%
df_pc=pd.read_csv('co-emissions-per-capita.csv')

# %%
plt.plot(df_pc['Year'],df_pc['CO2_percapita'], 'o')

# %% [markdown]
# ## Splitting total data into parts to fit polynomial regression function

# %%
# splitting dataframe by row index 
df_1 = df_pc.iloc[0:33,:] 
df_2 = df_pc.iloc[33:65,:]
df_3 = df_pc.iloc[32:34,:]

# %% [markdown]
# ##  Part 1 of dataset

# %%
plt.plot(df_1['Year'],df_1['CO2_percapita'], 'o')

# %% [markdown]
# ### Fitting polynomial regression function

# %%
# Fitting Polynomial Regression to the dataset
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=3)
X_poly = poly_reg.fit_transform(np.array(df_1['Year']).reshape(-1,1))
pol_reg = LinearRegression()
pol_reg.fit(X_poly, np.array(df_1['CO2_percapita']).reshape(-1,1))

# %% [markdown]
# ### Visualizing the Polymonial Regression fit

# %%
def viz_polymonial():
    plt.scatter(np.array(df_1['Year']).reshape(-1,1), np.array(df_1['CO2_percapita']).reshape(-1,1), color='red')
    plt.plot(np.array(df_1['Year']).reshape(-1,1), pol_reg.predict(poly_reg.fit_transform(np.array(df_1['Year']).reshape(-1,1))), color='blue')
    plt.title('Polynomial Regression Fit (Part1)')
    plt.xlabel('Year')
    plt.ylabel('CO2_percapita')
    plt.show()
    return
viz_polymonial()

# %% [markdown]
# ### Checking the fit by plotting Residual vs Predicted values

# %%
y_pred1=pol_reg.predict(poly_reg.fit_transform(np.array(df_1['Year']).reshape(-1,1)))

# %%
res = np.array(df_1['CO2_percapita']).reshape(-1,1)-y_pred1
res_stand = (res - res.mean())/res.std()
plt.scatter(y_pred1, res_stand )
plt.axhline(y = 0, color = 'red' )
plt.title("Predicted Values vs Residuals")
plt.xlabel("Predicted values")
plt.ylabel("Residuals")
plt.show()

# %% [markdown]
# ### Checking the fit by plotting Actual vs Predicted values

# %%
plt.scatter(y_pred1, np.array(df_1['CO2_percapita']).reshape(-1,1))
plt.title("Predicted Values vs Actual values")
plt.xlabel("Predicted values")
plt.ylabel("Actual values")
plt.show()

# %% [markdown]
# ### Interpolating CO2 emissions per capita for every month (Part 1 data) using Polynomial Regression fit

# %%
monthly_1= np.arange(1954,1986,1/12)
monthly_1
# Out:
# array([1954.        , 1954.08333333, 1954.16666667, 1954.25      ,
#        1954.33333333, 1954.41666667, 1954.5       , 1954.58333333,
#        1954.66666667, 1954.75      , 1954.83333333, 1954.91666667,
#        1955.        , 1955.08333333, 1955.16666667, 1955.25      ,
#        1955.33333333, 1955.41666667, 1955.5       , 1955.58333333,
#        1955.66666667, 1955.75      , 1955.83333333, 1955.91666667,
#        1956.        , 1956.08333333, 1956.16666667, 1956.25      ,
#        1956.33333333, 1956.41666667, 1956.5       , 1956.58333333,
#        1956.66666667, 1956.75      , 1956.83333333, 1956.91666667,
#        1957.        , 1957.08333333, 1957.16666667, 1957.25      ,
#        1957.33333333, 1957.41666667, 1957.5       , 1957.58333333,
#        1957.66666667, 1957.75      , 1957.83333333, 1957.91666667,
#        1958.        , 1958.08333333, 1958.16666667, 1958.25      ,
#        1958.33333333, 1958.41666667, 1958.5       , 1958.58333333,
# ...

# %%
y_pred_monthly1= pol_reg.predict(poly_reg.fit_transform(monthly_1.reshape(-1,1)))

# %% [markdown]
# ## Part 3 of dataset

# %% [markdown]
# ### Fitting polynomial regression function

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=3)
X_poly = poly_reg.fit_transform(np.array(df_2['Year']).reshape(-1,1))
pol_reg = LinearRegression()
pol_reg.fit(X_poly, np.array(df_2['CO2_percapita']).reshape(-1,1))

# %% [markdown]
# ### Visualizing the Polymonial Regression fit

# %%
def viz_polymonial():
    plt.scatter(np.array(df_2['Year']).reshape(-1,1), np.array(df_2['CO2_percapita']).reshape(-1,1), color='red')
    plt.plot(np.array(df_2['Year']).reshape(-1,1), pol_reg.predict(poly_reg.fit_transform(np.array(df_2['Year']).reshape(-1,1))), color='blue')
    plt.title('Polynomial Regression Fit (Part3)')
    plt.xlabel('Year')
    plt.ylabel('CO2_percapita')
    plt.show()
    return
viz_polymonial()

# %% [markdown]
# ### Interpolating CO2 emissions per capita for every month (Part 3 data) using Polynomial Regression fit

# %%
monthly_2= np.arange(1987,2020,1/12)
monthly_2
# Out:
# array([1987.        , 1987.08333333, 1987.16666667, 1987.25      ,
#        1987.33333333, 1987.41666667, 1987.5       , 1987.58333333,
#        1987.66666667, 1987.75      , 1987.83333333, 1987.91666667,
#        1988.        , 1988.08333333, 1988.16666667, 1988.25      ,
#        1988.33333333, 1988.41666667, 1988.5       , 1988.58333333,
#        1988.66666667, 1988.75      , 1988.83333333, 1988.91666667,
#        1989.        , 1989.08333333, 1989.16666667, 1989.25      ,
#        1989.33333333, 1989.41666667, 1989.5       , 1989.58333333,
#        1989.66666667, 1989.75      , 1989.83333333, 1989.91666667,
#        1990.        , 1990.08333333, 1990.16666667, 1990.25      ,
#        1990.33333333, 1990.41666667, 1990.5       , 1990.58333333,
#        1990.66666667, 1990.75      , 1990.83333333, 1990.91666667,
#        1991.        , 1991.08333333, 1991.16666667, 1991.25      ,
#        1991.33333333, 1991.41666667, 1991.5       , 1991.58333333,
# ...

# %%
y_pred_monthly2 = pol_reg.predict(poly_reg.fit_transform(monthly_2.reshape(-1,1)))

# %% [markdown]
# ## Part 2 of dataset

# %% [markdown]
# ### Fitting polynomial regression function

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree=1)
X_poly = poly_reg.fit_transform(np.array(df_3['Year']).reshape(-1,1))
pol_reg = LinearRegression()
pol_reg.fit(X_poly, np.array(df_3['CO2_percapita']).reshape(-1,1))

# %% [markdown]
# ### Visualizing the Polymonial Regression fit

# %%
def viz_polymonial():
    plt.scatter(np.array(df_3['Year']).reshape(-1,1), np.array(df_3['CO2_percapita']).reshape(-1,1), color='red')
    plt.plot(np.array(df_3['Year']).reshape(-1,1), pol_reg.predict(poly_reg.fit_transform(np.array(df_3['Year']).reshape(-1,1))), color='blue')
    plt.title('Truth or Bluff (Linear Regression)')
    plt.xlabel('Position level')
    plt.ylabel('Salary')
    plt.show()
    return
viz_polymonial()

# %% [markdown]
# ### Interpolating CO2 emissions per capita for every month (Part 2 data) using Polynomial Regression fit

# %%
monthly_3= np.arange(1986,(1987-1/12),1/12)
monthly_3
# Out:
# array([1986.        , 1986.08333333, 1986.16666667, 1986.25      ,
#        1986.33333333, 1986.41666667, 1986.5       , 1986.58333333,
#        1986.66666667, 1986.75      , 1986.83333333, 1986.91666667])

# %%
y_pred_monthly3 = pol_reg.predict(poly_reg.fit_transform(monthly_3.reshape(-1,1)))

# %% [markdown]
# ## Combining all the three parts of data and making a CO2 emissions percapita dataframe

# %%
y_pred_monthly1=list(itertools.chain.from_iterable(y_pred_monthly1.tolist()))
y_pred_monthly2=list(itertools.chain.from_iterable(y_pred_monthly2.tolist()))
y_pred_monthly3=list(itertools.chain.from_iterable(y_pred_monthly3.tolist()))

# %%
monthly = y_pred_monthly1+y_pred_monthly3+y_pred_monthly2

# %%
len(monthly)
# Out:
# 792

# %%
monthly = [round(num, 4) for num in monthly]
monthly
# Out:
# [0.0955,
#  0.095,
#  0.0947,
#  0.0943,
#  0.094,
#  0.0937,
#  0.0935,
#  0.0933,
#  0.0931,
#  0.093,
#  0.0928,
#  0.0928,
#  0.0927,
#  0.0927,
#  0.0927,
#  0.0928,
#  0.0929,
#  0.093,
#  0.0931,
#  0.0933,
#  0.0935,
#  0.0938,
#  0.094,
#  0.0943,
#  0.0947,
#  0.095,
#  0.0954,
#  0.0959,
#  0.0963,
#  0.0968,
#  0.0973,
#  0.0978,
#  0.0984,
#  0.099,
#  0.0997,
#  0.1003,
#  0.101,
#  0.1017,
#  0.1025,
#  0.1032,
#  0.104,
#  0.1049,
#  0.1057,
#  0.1066,
#  0.1075,
#  0.1085,
#  0.1094,
#  0.1104,
#  0.1114,
#  0.1125,
#  0.1136,
#  0.1147,
#  0.1158,
#  0.1169,
#  0.1181,
#  0.1193,
#  0.1205,
#  0.1218,
#  0.1231,
#  0.1244,
#  0.1257,
#  0.127,
#  0.1284,
#  0.1298,
#  0.1312,
#  0.1327,
#  0.1342,
#  0.1356,
#  0.1372,
#  0.1387,
#  0.1403,
#  0.1419,
#  0.1435,
#  0.1451,
#  0.1468,
#  0.1484,
#  0.1501,
#  0.1518,
#  0.1536,
#  0.1554,
#  0.1571,
#  0.1589,
#  0.1608,
#  0.1626,
#  0.1645,
#  0.1664,
#  0.1683,
#  0.1702,
#  0.1722,
#  0.1741,
#  0.1761,
# ...

# %%
x = np.arange(1954,2020)
Year=np.repeat(x,12)
len(Year)
# Out:
# 792

# %%
df_CO2 = pd.DataFrame(list(zip(Year, monthly)), columns =['Year', 'CO2_percapita']) 
df_CO2
# Out:
#      Year  CO2_percapita
# 0    1954         0.0955
# 1    1954         0.0950
# 2    1954         0.0947
# 3    1954         0.0943
# 4    1954         0.0940
# ..    ...            ...
# 787  2019         4.3797
# 788  2019         4.3862
# 789  2019         4.3928
# 790  2019         4.3993
# 791  2019         4.4059
#
# [792 rows x 2 columns]

# %% [markdown]
# ## Creating a csv file for CO2 emissions per capita

# %%
df_CO2.to_csv('CO2_percapita.csv', index=False)
